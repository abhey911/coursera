# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %%
#Data Science Notebook

# %% [markdown]
# Introduction
# This notebook is designed to cover various aspects of data science, including languages, libraries, tools, and arithmetic expressions. It also includes basic code examples to demonstrate data operations.

# %% [markdown]
# ## Data Science Languages
# Some popular languages for data science are:
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
# Some of the most commonly used data science libraries are:
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
# | Tool Name        | Purpose                     |
# |------------------|-----------------------------|
# | Jupyter Notebook | Code development and sharing |
# | RStudio          | Statistical computing        |
# | Apache Spark     | Big data processing          |
# | Tableau          | Data visualization           |

# %% [markdown]
# ## Arithmetic Expression Examples
# In this section, we will demonstrate simple arithmetic operations like addition, multiplication, and converting units.

# %%
# Multiply and add numbers
result = (5 * 6) + 8
result
# Out:
# 38

# %%
# Convert minutes to hours
minutes = 120
hours = minutes / 60
hours
# Out:
# 2.0

# %% [markdown]
# ## Objectives
# - Learn the basics of markdown syntax
# - Understand data science languages and libraries
# - Work with arithmetic expressions
# - Learn how to use code cells for computations

# %% [markdown]
# Abhey Chaurasia
